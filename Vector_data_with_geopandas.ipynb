# %% [markdown]
# <a href="https://colab.research.google.com/github/VrishankDesai/ISRO/blob/main/Vector_data_with_geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#creates dataframe(tables) and series(single column)
import os
#helps interact with file system and change directories
import shapely
#works with geometric objects(points,lines,polygon)
os.chdir(r'/content/')
#os.chdir() is used to change the current working directory in Python,r'' (raw string) ensures that backslashes (\) in file paths are treated correctly.

# %%
pd.Series(['Dehradun','Almora','Pithoragah'])
# Out:
# 0      Dehradun
# 1        Almora
# 2    Pithoragah
# dtype: object

# %%
city_names=pd.Series(['Dehradun','Almora','Pithoragah'])
population=pd.Series([100000,200000,300000])

# %%
pd.DataFrame({ 'City Name': city_names, 'Population': population })
# Out:
#     City Name  Population
# 0    Dehradun      100000
# 1      Almora      200000
# 2  Pithoragah      300000

# %%
file_name = '/content/Mumbai Local Train Dataset.csv'

# %%
import chardet

with open('/content/Mumbai Local Train Dataset.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))

print(result)

df = pd.read_csv('/content/Mumbai Local Train Dataset.csv', encoding=result['encoding'])
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
df
# Out:
#             Station Station Code            Line  \
# 0        Churchgate          CCG         Western
# 1      Marine Lines          MEL         Western
# 2       Charni Road          CYR         Western
# 3        Grant Road          GTR         Western
# 4    Mumbai Central         MMCT         Western
# ..              ...          ...             ...
# 197           Neral          NRL  Neral-Matheran
# 198       Jumapatti          JTT  Neral-Matheran
# 199       Waterpipe          WTP  Neral-Matheran
# 200      Aman Lodge         AMNA  Neral-Matheran
# 201        Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 0                                 0 KM                                0 min
# 1                                 1 KM                                3 min
# 2                                 1 KM                                2 min
# 3                                 1 KM                                3 min
# 4                                 1 KM                                2 min
# ..                                 ...                                  ...
# 197                               0 KM                                0 min
# 198                               5 KM                               46 min
# 199                               6 KM                               46 min
# 200                               7 KM                               50 min
# 201                               2 KM                               18 min
#
#                                                  About  Platforms  Tracks  \
# 0    The Fort area built by the British had three m...        4.0     4.0
# 1    Marine Lines (station code: MEL) is a railway ...        4.0     4.0
# 2    Charni Road (formerly Churney Road, station co...        4.0     4.0
# 3    Grant Road (/gra?nt/; station code: GTR), form...        4.0     4.0
# 4    Mumbai Central (formerly Bombay Central, stati...        9.0     9.0
# ..                                                 ...        ...     ...
# 197  Neral Junction is a railway station on the Cen...        2.0     2.0
# 198  Jummapatti railway station is a railway statio...        NaN     NaN
# 199  Water Pipe railway station is a railway statio...        NaN     NaN
# 200  Aman Lodge railway station is a railway statio...        NaN     NaN
# 201  Matheran Railway Station is the upper terminus...        NaN     NaN
#
#      Year of Opening                                  Nearby attractions  \
# 0              1867.0          Marine Drive,Nariman Point,Flora Fountain
# 1              1867.0  Marine Drive,Girgaum Chowpatty Beach,Taraporew...
# 2              1867.0  Girgaum Chowpatty Beach,Taraporewala Aquarium,...
# 3                 NaN  Taraporewala Aquarium,Girgaum Chowpatty Beach,...
# 4              1930.0  Haji Ali Dargah,Mahalakshmi Temple,Nehru Plane...
# ..                ...                                                ...
# 197               NaN  Matheran Hill Railway,Louisa Point,Charlotte Lake
# 198               NaN  Manas Mandir,Tungareshwar Wildlife Sanctuary,M...
# 199               NaN  Manas Mandir,Tungareshwar Wildlife Sanctuary,M...
# 200               NaN             Louisa Point,Echo Point,Panorama Point
# 201            1907.0         Charlotte Lake,Louisa Point,Panorama Point
#
#     Number of Passengers                                      Previous names
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN  Bellasis Road (Suburban station) Bombay Centra...
# ..                    ...                                                ...
# 197                   NaN                                                NaN
# 198                   NaN                                                NaN
# 199                   NaN                                                NaN
# 200                   NaN                                                NaN
# 201                   NaN                                                NaN
#
# [202 rows x 12 columns]

# %%
df.describe()
# Out:
#         Platforms      Tracks  Year of Opening
# count  197.000000  193.000000         83.000000
# mean     3.934010    4.792746       1914.542169
# std      2.505242    2.717334         52.801354
# min      1.000000    1.000000       1853.000000
# 25%      2.000000    3.000000       1867.500000
# 50%      3.000000    4.000000       1893.000000
# 75%      4.000000    6.000000       1966.000000
# max     15.000000   13.000000       2018.000000

# %%
df.head()
# Out:
#           Station Station Code     Line Distance From Previous of the Line  \
# 0      Churchgate          CCG  Western                               0 KM
# 1    Marine Lines          MEL  Western                               1 KM
# 2     Charni Road          CYR  Western                               1 KM
# 3      Grant Road          GTR  Western                               1 KM
# 4  Mumbai Central         MMCT  Western                               1 KM
#
#   Time taken From Previous of the Line  \
# 0                                0 min
# 1                                3 min
# 2                                2 min
# 3                                3 min
# 4                                2 min
#
#                                                About  Platforms  Tracks  \
# 0  The Fort area built by the British had three m...        4.0     4.0
# 1  Marine Lines (station code: MEL) is a railway ...        4.0     4.0
# 2  Charni Road (formerly Churney Road, station co...        4.0     4.0
# 3  Grant Road (/gra?nt/; station code: GTR), form...        4.0     4.0
# 4  Mumbai Central (formerly Bombay Central, stati...        9.0     9.0
#
#    Year of Opening                                  Nearby attractions  \
# 0            1867.0          Marine Drive,Nariman Point,Flora Fountain
# 1            1867.0  Marine Drive,Girgaum Chowpatty Beach,Taraporew...
# 2            1867.0  Girgaum Chowpatty Beach,Taraporewala Aquarium,...
# 3               NaN  Taraporewala Aquarium,Girgaum Chowpatty Beach,...
# 4            1930.0  Haji Ali Dargah,Mahalakshmi Temple,Nehru Plane...
#
#   Number of Passengers                                      Previous names
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  Bellasis Road (Suburban station) Bombay Centra...

# %%
df.tail()
# Out:
#         Station Station Code            Line  \
# 197       Neral          NRL  Neral-Matheran
# 198   Jumapatti          JTT  Neral-Matheran
# 199   Waterpipe          WTP  Neral-Matheran
# 200  Aman Lodge         AMNA  Neral-Matheran
# 201    Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 197                               0 KM                                0 min
# 198                               5 KM                               46 min
# 199                               6 KM                               46 min
# 200                               7 KM                               50 min
# 201                               2 KM                               18 min
#
#                                                  About  Platforms  Tracks  \
# 197  Neral Junction is a railway station on the Cen...        2.0     2.0
# 198  Jummapatti railway station is a railway statio...        NaN     NaN
# 199  Water Pipe railway station is a railway statio...        NaN     NaN
# 200  Aman Lodge railway station is a railway statio...        NaN     NaN
# 201  Matheran Railway Station is the upper terminus...        NaN     NaN
#
#      Year of Opening                                  Nearby attractions  \
# 197               NaN  Matheran Hill Railway,Louisa Point,Charlotte Lake
# 198               NaN  Manas Mandir,Tungareshwar Wildlife Sanctuary,M...
# 199               NaN  Manas Mandir,Tungareshwar Wildlife Sanctuary,M...
# 200               NaN             Louisa Point,Echo Point,Panorama Point
# 201            1907.0         Charlotte Lake,Louisa Point,Panorama Point
#
#     Number of Passengers  Previous names
# 197                   NaN            NaN
# 198                   NaN            NaN
# 199                   NaN            NaN
# 200                   NaN            NaN
# 201                   NaN            NaN

# %%
df['Station Code'] #
# Out:
# 0       CCG
# 1       MEL
# 2       CYR
# 3       GTR
# 4      MMCT
#        ...
# 197     NRL
# 198     JTT
# 199     WTP
# 200    AMNA
# 201     MAE
# Name: Station Code, Length: 202, dtype: object

# %%
df['Station Code'][2]
# Out:
# 'CYR'

# %%
df['Station Code'][4:8]
# Out:
# 4    MMCT
# 5      MX
# 6      PL
# 7    PBHD
# Name: Station Code, dtype: object

# %%
df[df['Station']=='Jumapatti']
# Out:
#        Station Station Code            Line  \
# 198  Jumapatti          JTT  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 198                               5 KM                               46 min
#
#                                                  About  Platforms  Tracks  \
# 198  Jummapatti railway station is a railway statio...        NaN     NaN
#
#      Year of Opening                                  Nearby attractions  \
# 198               NaN  Manas Mandir,Tungareshwar Wildlife Sanctuary,M...
#
#     Number of Passengers  Previous names
# 198                   NaN            NaN

# %%
df['Lat in Min'] = df['Latitude']*60
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-d9b7f8f33939> in <cell line: 0>()
# ----> 1 df['Lat in Min'] = df['Latitude']*60
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Latitude'

# %%
df['Station Code'].index
# Out:
# RangeIndex(start=0, stop=202, step=1)

# %%
df['Station Code'].reindex([2, 0, 1])
# Out:
# 2    CYR
# 0    CCG
# 1    MEL
# Name: Station Code, dtype: object

# %%
df.sort_values(by=['Distance From Previous of the Line'])
# Out:
#          Station Station Code                 Line  \
# 0     Churchgate          CCG              Western
# 77          CSMT      CSMT/ST            Central 2
# 114         CSMT      CSMT/ST              Harbour
# 139        Thane          TNA        Trans Harbour
# 37          CSMT      CSMT/ST            Central 1
# ..           ...          ...                  ...
# 140       Airoli         AIRL        Trans Harbour
# 176      Vangaon          VGN  Dahanu-Virar-Panvel
# 156  Bamandongri        BMNDG                 Uran
# 109      Atagaon          ATG            Central 2
# 35       Vangaon          VGN              Western
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 0                                 0 KM                                0 min
# 77                                0 KM                                0 min
# 114                               0 KM                                0 min
# 139                               0 KM                                0 min
# 37                                0 KM                                0 min
# ..                                 ...                                  ...
# 140                               8 KM                                8 min
# 176                               9 KM                                9 min
# 156                               9 KM                               12 min
# 109                               9 KM                                9 min
# 35                                9 KM                                9 min
#
#                                                  About  Platforms  Tracks  \
# 0    The Fort area built by the British had three m...        4.0     4.0
# 77   Chhatrapati Shivaji Terminus (officially Chhat...        7.0     7.0
# 114  Chhatrapati Shivaji Terminus (officially Chhat...        7.0     7.0
# 139  Thane (formerly Thana, station code: TNA) is a...       10.0    10.0
# 37   Chhatrapati Shivaji Terminus (officially Chhat...        7.0     7.0
# ..                                                 ...        ...     ...
# 140  Airoli is a railway station on the Harbour lin...        2.0     2.0
# 176  Vangaon is a railway station on the Western li...        3.0     4.0
# 156  Bamandongri railway station (station code: BMN...        2.0     2.0
# 109  Atgaon is a railway station on the Central lin...        2.0     4.0
# 35   Vangaon is a railway station on the Western li...        3.0     4.0
#
#      Year of Opening                                  Nearby attractions  \
# 0              1867.0          Marine Drive,Nariman Point,Flora Fountain
# 77             1878.0  Gateway of India,Chhatrapati Shivaji Maharaj V...
# 114               NaN  Gateway of India,Chhatrapati Shivaji Maharaj V...
# 139               NaN    Upvan Lake,Talao Pali,Tikuji-ni-Wadi Water Park
# 37             1878.0  Gateway of India,Chhatrapati Shivaji Maharaj V...
# ..                ...                                                ...
# 140               NaN  Airoli Bridge,Airoli Mangrove Garden,Shree Swa...
# 176               NaN             Kelva Beach,Mahim Beach,Shirgaon Beach
# 156            2018.0                Elephanta Caves,Uran Beach,Sagargad
# 109               NaN             Chanderi Fort,Mahuli Fort,Asangaon Dam
# 35                NaN             Kelva Beach,Mahim Beach,Shirgaon Beach
#
#     Number of Passengers                   Previous names
# 0                     NaN                             NaN
# 77                    NaN  Victoria Terminus,Bori Station
# 114                   NaN                             NaN
# 139                   NaN                             NaN
# 37                    NaN  Victoria Terminus,Bori Station
# ..                    ...                             ...
# 140                   NaN                             NaN
# 176                   NaN                             NaN
# 156                   NaN                             NaN
# 109                   NaN                             NaN
# 35                    NaN                             NaN
#
# [202 rows x 12 columns]

# %%
# !pip uninstall geopandas
# Out:
# Found existing installation: geopandas 1.0.1
# Uninstalling geopandas-1.0.1:
#   Would remove:
#     /usr/local/lib/python3.11/dist-packages/geopandas-1.0.1.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/geopandas/*
# Proceed (Y/n)? Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/uninstall.py", line 106, in run
#     uninstall_pathset = req.uninstall(
#                         ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/req/req_install.py", line 722, in uninstall
#     uninstalled_pathset.remove(auto_confirm, verbose)
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/req/req_uninstall.py", line 364, in remove
#     if auto_confirm or self._allowed_to_proceed(verbose):
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/req/req_uninstall.py", line 404, in _allowed_to_proceed
#     return ask("Proceed (Y/n)? ", ("y", "n", "")) != "n"
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/utils/misc.py", line 235, in ask
#     response = input(message)
#                ^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.11/logging/__init__.py", line 1526, in critical
#     def critical(self, msg, *args, **kwargs):
#
# KeyboardInterrupt
# ^C

# %%
# !pip install geopandas
# !pip install mapclassify
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Collecting mapclassify
#   Downloading mapclassify-2.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (3.4.2)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (1.26.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->mapclassify) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->mapclassify) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.17.0)
# Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.8.1

# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from geopandas import GeoSeries

# %%
gpd.__version__
# Out:
# '1.0.1'

# %%
vector_file = '/content/in_district_shp.png'

# %%
import os
print(os.path.exists('/content/in_district_shp.png'))
# Out:
# True

# %%
vector_file = '/content/in_district_shp.png'  # Replace with the actual path
states = gpd.read_file(vector_file)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# <ipython-input-13-6b87499c5681> in <cell line: 0>()
#       1 vector_file = '/content/in_district_shp.png'  # Replace with the actual path
# ----> 2 states = gpd.read_file(vector_file)
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     292
#     293     if engine == "pyogrio":
# --> 294         return _read_file_pyogrio(
#     295             filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296         )
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     545         kwargs["columns"] = kwargs.pop("include_fields")
#     546
# --> 547     return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#     548
#     549
#
# /usr/local/lib/python3.11/dist-packages/pyogrio/geopandas.py in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     263         # as numpy does not directly support timezones.
#     264         kwargs["datetime_as_string"] = True
# --> 265     result = read_func(
#     266         path_or_buffer,
#     267         layer=layer,
#
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#     196     dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
#     197
# --> 198     return ogr_read(
#     199         get_vsi_path_or_buffer(path_or_buffer),
#     200         layer=layer,
#
# pyogrio/_io.pyx in pyogrio._io.ogr_read()
#
# pyogrio/_io.pyx in pyogrio._io.ogr_open()
#
# DataSourceError: '/content/in_district_shp.png' not recognized as being in a supported file format. It might help to specify the correct driver explicitly by prefixing the file path with '<DRIVER>:', e.g. 'CSV:path'.

# %%
type(india)
# Out:
# NoneType

# %%
india.geometry.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-052a69f3a2a5> in <cell line: 0>()
# ----> 1 india.geometry.name
#
# AttributeError: 'NoneType' object has no attribute 'geometry'

# %%
india.crs

# %%
india = india.rename(columns={'geometry': 'borders'}).set_geometry('borders')

# %%
india.head()

# %%
india.plot(figsize=(18, 14))

# %%
vector_file = r'/content/drive/MyDrive/DLP_Data/India/STATE_BOUNDARY.zip'

# %%
states = gpd.read_file(vector_file)

# %%
states

# %%
states.plot()

# %%
vector_file = r'Administrative_Boundary_Database.zip!MAJOR_TOWNS.shp'

# %%
india = gpd.read_file(vector_file)

# %%
india.head()

# %%
india.plot()

# %%
plt.close()

# %%
url = "http://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_land.geojson"
gdf = gpd.read_file(url)

# %%
gdf

# %%
gdf.plot()

# %%
india.head()

# %%
india['state'].unique()

# %%
gdf_mask = gpd.read_file('STATE_BOUNDARY.shp')

# %%
gdf_mask.head()

# %%
file_name = 'DISTRICT_BOUNDARY.shp'

# %%
df = gpd.read_file(file_name, mask=gdf_mask[gdf_mask.STATE=="ASSAM"],)

# %%
df.plot()

# %%
bbox = (4.9e6, 4e6, 5.4e6, 4.2e6)
gdf = gpd.read_file(file_name,bbox=bbox)

# %%
gdf.plot()

# %%
gdf = gpd.read_file(file_name,rows=slice(80, 180))

# %%
gdf.plot()

# %%
gdf = gpd.read_file(file_name, columns=["STATE"])

# %%
gdf.head()

# %%
gdf = gpd.read_file(file_name, where="STATE='UTTAR>KHAND'")

# %%
gdf.plot()

# %%
vector_file = '/content/drive/MyDrive/DLP_Data/GDB_File/Karimnagar_2020.gdb'

# %%
layers = gpd.list_layers(vector_file)

# %%
layers

# %%
lulc  = gpd.read_file(vector_file, layer='LULC_poly')

# %%
lulc.plot()

# %%
plt.close()

# %%
df

# %%
gson = '/content/drive/MyDrive/DLP_Data/India/almora.geojson'
uk = gpd.read_file(gson)

# %%
uk.head()

# %%
file_name = '/content/drive/MyDrive/DLP_Data/India/MAJOR_TOWNS.shp'
gdf = gpd.read_file(file_name)

# %%
subset = india[india['state']=='TAMIL NADU']

# %%
subset.plot(figsize=(10, 10))

# %%
subset.explore('district', legend=False)

# %%
plt.close()
